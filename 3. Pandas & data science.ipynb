# %% [markdown]
# # Pandas & Data science

# %%
import pandas as pd
import numpy as np

# %%
# main purpose of pandas is to read datasets and analyze them
# plus points are it shows data in well manner order and shows the shape at bottom

# %% [markdown]
# ### .csv file

# %%
# csv
df = pd.read_csv('datasets/pandas/pokemon_data.csv')
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
# starting rows
df.head(7)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
# 5  5             Charmeleon   Fire     NaN  58      64       58       80
# 6  6              Charizard   Fire  Flying  78      84       78      109
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False
# 5       65     80           1      False
# 6       85    100           1      False

# %%
# last rows
df.tail(3)
# Out:
#        #                 Name   Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# 797  720  HoopaHoopa Confined  Psychic  Ghost  80     110       60      150
# 798  720   HoopaHoopa Unbound  Psychic   Dark  80     160       60      170
# 799  721            Volcanion     Fire  Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 797      130     70           6       True
# 798      130     80           6       True
# 799       90     70           6       True

# %% [markdown]
# ### .xlsx file

# %%
df_xlsx = pd.read_excel('datasets/pandas/pokemon_data.xlsx')
df_xlsx
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
# same head() and tail()
df_xlsx.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %% [markdown]
# ### .txt file

# %%
# read_csv() is used to read .txt files
df_txt = pd.read_csv('datasets/pandas/pokemon_data.txt', delimiter='\t')
df_txt

# head() and tail() are same
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %% [markdown]
# ### .html file

# %%
# data will be fetch apart from render HTML here
# df_html = pd.read_html('http://www.fdic.gov/bank/individual/failed/banklist.html')
# df_html

# %% [markdown]
# ## Creating your own DataFrame

# %%
# works like jSON format i.e. "key" = "values"
mydf = pd.DataFrame({'Name':['Hamza', 'Asnan', 'Saqiq', 'Saif', 'Istafa', 'Zeeshan'], 'Age':['22','21','32','24','20','26']})
mydf
# Out:
#       Name Age
# 0    Hamza  22
# 1    Asnan  21
# 2    Saqiq  32
# 3     Saif  24
# 4   Istafa  20
# 5  Zeeshan  26

# %%
# head() and tail() are same
mydf.head()
# Out:
#      Name Age
# 0   Hamza  22
# 1   Asnan  21
# 2   Saqiq  32
# 3    Saif  24
# 4  Istafa  20

# %% [markdown]
# ## Operations on Dataframes

# %%
# describe()
# min, max, mean, std, count etc.
df.describe()
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %%
# describe a single Column/feature
df.HP.describe()
# Out:
# count    800.000000
# mean      69.258750
# std       25.534669
# min        1.000000
# 25%       50.000000
# 50%       65.000000
# 75%       80.000000
# max      255.000000
# Name: HP, dtype: float64

# %% [markdown]
# ### Most Important function in ML

# %%
# unique()
# dataframe.col_name.unique()
df.HP.unique()
# Out:
# array([ 45,  60,  80,  39,  58,  78,  44,  59,  79,  50,  40,  65,  63,
#         83,  30,  55,  35,  75,  70,  90,  46,  61,  81,  95,  38,  73,
#        115, 140,  10,  25,  52, 105,  85, 250,  20, 130,  48, 160,  41,
#         91, 106, 100, 125, 190, 255,  28,  68, 150,  31,   1,  64,  84,
#        104,  72, 144, 170, 110,  43,  66,  86,  99,  76,  53,  37,  77,
#         67,  97, 111,  49,  71, 103,  57, 108, 135,  74,  69, 120, 116,
#         62,  54,  36,  51, 114, 165, 109,  89,  92,  56,  88, 123, 101,
#         82,  42, 126], dtype=int64)

# %%
# value_counts()
# dataframe.col_name.value_counts()
# dataframe.value_counts()
df.value_counts()
# Out:
# #    Name                   Type 1   Type 2  HP   Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 721  Volcanion              Fire     Water   80   110     120      130      90       70     6           True         1
# 269  Dustox                 Bug      Poison  60   50      70       50       90       65     3           False        1
# 250  Ho-oh                  Fire     Flying  106  130     90       110      154      90     2           True         1
# 251  Celebi                 Psychic  Grass   100  100     100      100      100      100    2           False        1
# 254  SceptileMega Sceptile  Grass    Dragon  70   110     75       145      85       145    3           False        1
#                                                                                                                     ..
# 485  Heatran                Fire     Steel   91   90      106      130      106      77     4           True         1
# ...

# %%
df.HP.value_counts()
# Out:
# 60     67
# 50     63
# 70     57
# 65     46
# 75     43
#        ..
# 92      1
# 88      1
# 81      1
# 250     1
# 1       1
# Name: HP, Length: 94, dtype: int64

# %%
# getting datatypes
df.HP.dtypes

# for full table
df.dtypes
# Out:
# #              int64
# Name          object
# Type 1        object
# Type 2        object
# HP             int64
# Attack         int64
# Defense        int64
# Sp. Atk        int64
# Sp. Def        int64
# Speed          int64
# Generation     int64
# Legendary       bool
# dtype: object

# %% [markdown]
# ## Finding the missing data

# %% [markdown]
# Note: It is important to remove all the NaN or null values from the datasets because ML is all about matrix multiplication and whatever get multiply by null/NaN will results zero from there the prediction for a model layer will become zero and hence everything will be ruined.

# %%
# finding all the null values
df.isnull().sum()
# Out:
# #               0
# Name            0
# Type 1          0
# Type 2        386
# HP              0
# Attack          0
# Defense         0
# Sp. Atk         0
# Sp. Def         0
# Speed           0
# Generation      0
# Legendary       0
# dtype: int64

# %% [markdown]
# After getting all the null values, you have two options
# 1. Fill the missing values
# 2. Drop the missing values

# %% [markdown]
# ### Filling the missing values

# %%
# df.fillna(value, inplace=True)
# if you don't use 'inplace=True' this wont work in whole notebook. This will be true just in this cell
df.fillna(0, inplace=True)
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire       0  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df.isnull().sum()
# Out:
# #             0
# Name          0
# Type 1        0
# Type 2        0
# HP            0
# Attack        0
# Defense       0
# Sp. Atk       0
# Sp. Def       0
# Speed         0
# Generation    0
# Legendary     0
# dtype: int64

# %% [markdown]
# ### Dropping the missing values

# %% [markdown]
# It is a bad practice as ML model needs approx 80k rows for training so the more you have the better the model will train itself. Hence, filling the missing values is preferred.

# %%
# axis = 0 means it will apply to all the rows
df.dropna(inplace=True, axis=0)
df.isnull().sum()
# Out:
# #             0
# Name          0
# Type 1        0
# Type 2        0
# HP            0
# Attack        0
# Defense       0
# Sp. Atk       0
# Sp. Def       0
# Speed         0
# Generation    0
# Legendary     0
# dtype: int64

# %%
# after droping values, the shape will change i.e. rows will be decreased
df.shape
# Out:
# (414, 12)

# %% [markdown]
# ### Renaming a Column

# %%
# axis = 1 will perform ftn on full colmn
df.rename(columns={'HP':'My Column'})
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...
