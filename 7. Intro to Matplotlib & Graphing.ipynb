# %% [markdown]
# # Intro to Matplotlib & Graphing in Python
#
# !important:
# Always keep in mind steps like Data preparation and Data visualization

# %%
# mat == matlab
# plot == plotting the graph
# lib == library
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %% [markdown]
# This line is used in jupyter notebook to plot the graph inside the cell or this book. Otherwise, graphs will be plotted outside this windows in another windows, when you will be linking graphs or data outside the notebook

# %%
import numpy as np
x = np.linspace(0,5,11)
y = x ** 2

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
plt.plot(x, y)

# %% [markdown]
# ## Custom Graph & Basic Commands

# %%
# values on x & y axis
names = ['Asnan','Hamza','Saif','Talha']
gpa = [3.3,2.94,2.5,2.6]

# %%
# title
plt.title("CGPA 4th Semester")

# label the axis
plt.xlabel("Names")
plt.ylabel("CGPA")

# plotting the graph
# color ==> RGB
plt.plot(names, gpa, 'g') # 'g' is green color

# %%
# other attributes works the same way
plt.scatter(names, gpa)

# %%
plt.bar(names, gpa)
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# ## Multiplot on same canvas

# %%
# plt.subplot(rows, columns, plot_number)
# meaning, 1 row will have 2 column(plots)

plt.subplot(1,3,1) # first plot
plt.plot(x, y, 'r')

plt.subplot(1,3,2) # second plot
plt.plot(y, x, 'g')

plt.subplot(1,3,3) # third plot
plt.bar(x,y)
# Out:
# <BarContainer object of 11 artists>

# %%
# reversing the plot into rows
# 3 rows & 1 column each
plt.subplot(3,1,1)
plt.plot(x,y,'r')

plt.subplot(3,1,2)
plt.plot(y,x,'g')

plt.subplot(3,1,3)
plt.plot(x,y)

# %%
# dotted graph
plt.subplot(1,2,1) # first plot
plt.plot(x, y, 'r--') # dotted line

plt.subplot(1,2,2) # second plot
plt.plot(y, x, 'go-') # circular line ( '*-' can also be used)

# %%
plt.plot(x, y, 'ro')

# %%
plt.plot(y, x, 'g*')

# %% [markdown]
# ## Matplotlib Object Oriented Method
#
# As the name is self-explanatory, we will create object and then use that object to call various methods and attributes as in general concept of OOP
#
# Basic Steps:
#
# - Create figure()
# - add axes
# - plot graphs using axes

# %%
# Creating Object (empy canvas)
fig = plt.figure()

# adding axes (we will use this axes to add graph into it)
axes = fig.add_axes([0.1, 0.1, 0.8, 0.8]) # left, bottom, width, height (position, scale)

# plotting graph
axes.plot(x,y,'g--')

# %%
# plotting multiple graph in same canvas
fig = plt.figure()
axes = fig.add_axes([0.1, 0.1, 0.8, 0.8]) # left, bottom, width, height
axes.plot(x,y,'g')
axes.plot(y,x,'r')
axes.plot(y,y,'b')

# %% [markdown]
# #### Changes in commands while using 'axes'

# %%
fig = plt.figure()
axes = fig.add_axes([0.1, 0.1, 0.8, 0.8]) # left, bottom, width, height
axes.plot(x,y,'g')
axes.plot(y,x,'r')

# changes 'set' is being used here
axes.set_xlabel('x values')
axes.set_ylabel('y values')
axes.set_title("This is title")
# Out:
# Text(0.5, 1.0, 'This is title')

# %% [markdown]
# ### Axes within Axes

# %%
fig = plt.figure()

axes1 = fig.add_axes([0.1, 0.1, 0.8, 0.8]) # left, bottom, width, height
axes2 = fig.add_axes([0.2, 0.5, 0.4, 0.3]) # left, bottom, width, height

# larger figure
axes1.plot(x,y,'g')
axes1.set_title('1st Axes')

# smaller figure
axes2.plot(y,x,'r--')
axes2.set_title("2nd Axes")
# Out:
# Text(0.5, 1.0, '2nd Axes')
