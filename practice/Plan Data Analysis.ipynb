# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data/Plant_1_Weather_Sensor_Data.csv')
df
# Out:
#                 DATE_TIME  PLANT_ID       SOURCE_KEY  AMBIENT_TEMPERATURE  \
# 0     2020-05-15 00:00:00   4135001  HmiyD2TTLFNqkNe            25.184316
# 1     2020-05-15 00:15:00   4135001  HmiyD2TTLFNqkNe            25.084589
# 2     2020-05-15 00:30:00   4135001  HmiyD2TTLFNqkNe            24.935753
# 3     2020-05-15 00:45:00   4135001  HmiyD2TTLFNqkNe            24.846130
# 4     2020-05-15 01:00:00   4135001  HmiyD2TTLFNqkNe            24.621525
# ...                   ...       ...              ...                  ...
# 3177  2020-06-17 22:45:00   4135001  HmiyD2TTLFNqkNe            22.150570
# 3178  2020-06-17 23:00:00   4135001  HmiyD2TTLFNqkNe            22.129816
# 3179  2020-06-17 23:15:00   4135001  HmiyD2TTLFNqkNe            22.008275
# 3180  2020-06-17 23:30:00   4135001  HmiyD2TTLFNqkNe            21.969495
# 3181  2020-06-17 23:45:00   4135001  HmiyD2TTLFNqkNe            21.909288
#
#       MODULE_TEMPERATURE  IRRADIATION
# 0              22.857507          0.0
# ...

# %%
df.isnull().sum()
# Out:
# DATE_TIME              0
# PLANT_ID               0
# SOURCE_KEY             0
# AMBIENT_TEMPERATURE    0
# MODULE_TEMPERATURE     0
# IRRADIATION            0
# dtype: int64

# %%
df.describe()
# Out:
#         PLANT_ID  AMBIENT_TEMPERATURE  MODULE_TEMPERATURE  IRRADIATION
# count     3182.0          3182.000000         3182.000000  3182.000000
# mean   4135001.0            25.531606           31.091015     0.228313
# std          0.0             3.354856           12.261222     0.300836
# min    4135001.0            20.398505           18.140415     0.000000
# 25%    4135001.0            22.705182           21.090553     0.000000
# 50%    4135001.0            24.613814           24.618060     0.024653
# 75%    4135001.0            27.920532           41.307840     0.449588
# max    4135001.0            35.252486           65.545714     1.221652

# %%
df.dtypes
# Out:
# DATE_TIME               object
# PLANT_ID                 int64
# SOURCE_KEY              object
# AMBIENT_TEMPERATURE    float64
# MODULE_TEMPERATURE     float64
# IRRADIATION            float64
# dtype: object

# %%
df.IRRADIATION.unique()
# Out:
# array([0.00000000e+00, 8.62721241e-04, 5.88695719e-03, ...,
#        2.34457015e-02, 7.00688981e-03, 3.90831153e-05])

# %%
df.head()
# Out:
#              DATE_TIME  PLANT_ID       SOURCE_KEY  AMBIENT_TEMPERATURE  \
# 0  2020-05-15 00:00:00   4135001  HmiyD2TTLFNqkNe            25.184316
# 1  2020-05-15 00:15:00   4135001  HmiyD2TTLFNqkNe            25.084589
# 2  2020-05-15 00:30:00   4135001  HmiyD2TTLFNqkNe            24.935753
# 3  2020-05-15 00:45:00   4135001  HmiyD2TTLFNqkNe            24.846130
# 4  2020-05-15 01:00:00   4135001  HmiyD2TTLFNqkNe            24.621525
#
#    MODULE_TEMPERATURE  IRRADIATION
# 0           22.857507          0.0
# 1           22.761668          0.0
# 2           22.592306          0.0
# 3           22.360852          0.0
# 4           22.165423          0.0

# %%
df.tail()
# Out:
#                 DATE_TIME  PLANT_ID       SOURCE_KEY  AMBIENT_TEMPERATURE  \
# 3177  2020-06-17 22:45:00   4135001  HmiyD2TTLFNqkNe            22.150570
# 3178  2020-06-17 23:00:00   4135001  HmiyD2TTLFNqkNe            22.129816
# 3179  2020-06-17 23:15:00   4135001  HmiyD2TTLFNqkNe            22.008275
# 3180  2020-06-17 23:30:00   4135001  HmiyD2TTLFNqkNe            21.969495
# 3181  2020-06-17 23:45:00   4135001  HmiyD2TTLFNqkNe            21.909288
#
#       MODULE_TEMPERATURE  IRRADIATION
# 3177           21.480377          0.0
# 3178           21.389024          0.0
# 3179           20.709211          0.0
# 3180           20.734963          0.0
# 3181           20.427972          0.0

# %%
df.SOURCE_KEY.value_counts()
# Out:
# HmiyD2TTLFNqkNe    3182
# Name: SOURCE_KEY, dtype: int64

# %%
for index, row in df.iterrows():
    print(index, row['PLANT_ID'])
# Out:
# 0 4135001
# 1 4135001
# 2 4135001
# 3 4135001
# 4 4135001
# 5 4135001
# 6 4135001
# 7 4135001
# 8 4135001
# 9 4135001
# 10 4135001
# 11 4135001
# 12 4135001
# 13 4135001
# 14 4135001
# 15 4135001
# 16 4135001
# 17 4135001
# 18 4135001
# 19 4135001
# 20 4135001
# 21 4135001
# 22 4135001
# 23 4135001
# 24 4135001
# 25 4135001
# 26 4135001
# 27 4135001
# 28 4135001
# 29 4135001
# 30 4135001
# 31 4135001
# 32 4135001
# 33 4135001
# 34 4135001
# 35 4135001
# 36 4135001
# 37 4135001
# 38 4135001
# 39 4135001
# 40 4135001
# 41 4135001
# 42 4135001
# 43 4135001
# 44 4135001
# 45 4135001
# 46 4135001
# 47 4135001
# 48 4135001
# 49 4135001
# 50 4135001
# 51 4135001
# 52 4135001
# 53 4135001
# 54 4135001
# 55 4135001
# 56 4135001
# 57 4135001
# 58 4135001
# 59 4135001
# 60 4135001
# 61 4135001
# 62 4135001
# 63 4135001
# 64 4135001
# 65 4135001
# 66 4135001
# 67 4135001
# 68 4135001
# 69 4135001
# 70 4135001
# 71 4135001
# 72 4135001
# 73 4135001
# 74 4135001
# 75 4135001
# 76 4135001
# ...

# %%
df.loc[df['SOURCE_KEY']=="wCURE6d3bPkepu2"].head(20)
# Out:
# Empty DataFrame
# Columns: [DATE_TIME, PLANT_ID, SOURCE_KEY, AMBIENT_TEMPERATURE, MODULE_TEMPERATURE, IRRADIATION]
# Index: []

# %%
df[3:5]
# Out:
#              DATE_TIME  PLANT_ID       SOURCE_KEY  AMBIENT_TEMPERATURE  \
# 3  2020-05-15 00:45:00   4135001  HmiyD2TTLFNqkNe            24.846130
# 4  2020-05-15 01:00:00   4135001  HmiyD2TTLFNqkNe            24.621525
#
#    MODULE_TEMPERATURE  IRRADIATION
# 3           22.360852          0.0
# 4           22.165423          0.0
